# %%
from scnet1 import scnet50
model = scnet50(pretrained=False)
import torch.nn as nn
import torch
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

# %%
import os
import sys
from collections import OrderedDict
import sys
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.transforms import Lambda
import numpy as np
import pandas as pd
from PIL import Image
from skimage import io
from torch.utils.data import Dataset

class MEbeautyDataset(Dataset):

    """
    SCUT-FBP5500 dataset
    """

    def __init__(self, train=True, transform=None):
        split_train = 'train.txt'
        split_test =  'test.txt'
        if train:
            self.face_img = pd.read_csv(split_train, sep=' ',names=['image','score'], header=None).iloc[:, 0].tolist()
            self.face_score = pd.read_csv(split_train,sep=' ',names=['image','score'], header=None).iloc[:,1].tolist()
           # self.face_score = pd.read_csv(split_train,sep=' ',names=['image','score'], header=None).iloc[:,1].tolist()
            #self.face_score=8.65
            #self.face_score = [x - 1 for x in self.face_score]
        else:
            self.face_img = pd.read_csv(split_test,sep=' ',names=['image','score'], header=None).iloc[:, 0].tolist()
            self.face_score = pd.read_csv(split_test, sep=' ', names=['image','score'], header=None).iloc[:, 1].tolist()
            #self.face_score = [x - 1 for x in self.face_score]
        self.transform = transform
            
        
        
    def __len__(self):
        return len(self.face_img)

    def __getitem__(self, index):
        #image = io.imread('/home/ubuntu/SCUT5500/Images/'+str(self.face_img[index]))
        image=Image.open(self.face_img[index])
        score = self.face_score[index]
       # sample = {'image': image, 'score': score, 'class': round(score) - 1, 'filename': self.face_img[index]}

        
        if self.transform:
           image = self.transform(image)
        sample = image,  score
        return sample


def load_scutfbp5500_64():

    data_transforms = {
        'train': transforms.Compose([
            transforms.Resize(224),
            transforms.RandomCrop(224),
            transforms.RandomRotation(30),
            # transforms.ColorJitter(),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'test': transforms.Compose([
            transforms.Resize(224),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
    }

    train_loader = torch.utils.data.DataLoader(MEbeautyDataset(train=True, transform=data_transforms['train']),
                                               batch_size=128, shuffle=True, num_workers=50,
                                               pin_memory=True)
    test_loader = torch.utils.data.DataLoader(MEbeautyDataset(train=False, transform=data_transforms['test']),
                                              batch_size=128, shuffle=False, num_workers=50,
                                              pin_memory=True)

    return test_loader, train_loader
        
train,test = load_scutfbp5500_64()

# %%
for i, (inputs, targets) in enumerate(train):
    print(inputs.shape)
    print(targets.shape)
# Out:
# torch.Size([128, 3, 224, 224])
# torch.Size([128])
# torch.Size([128, 3, 224, 224])
# torch.Size([128])
# torch.Size([128, 3, 224, 224])
# torch.Size([128])
# torch.Size([128, 3, 224, 224])
# torch.Size([128])
# torch.Size([128, 3, 224, 224])
# torch.Size([128])
# torch.Size([128, 3, 224, 224])
# torch.Size([128])
# torch.Size([128, 3, 224, 224])
# torch.Size([128])
# torch.Size([128, 3, 224, 224])
# torch.Size([128])
# torch.Size([128, 3, 224, 224])
# torch.Size([128])
# torch.Size([106, 3, 224, 224])
# torch.Size([106])

# %%
#model.load_state_dict(torch.load('model.pt'))
#epoch=13
for epoch in range(10):
    print(epoch)
    # enumerate mini batches
    for i, (inputs, targets) in enumerate(train):
# clear the gradients
        #print(inputs.shape)
        optimizer.zero_grad()
# compute the model output
        yhat = model(inputs)
# calculate loss
        yhat=yhat.reshape(yhat.shape[0])
        loss = criterion(yhat, targets.float())
        print(loss)
        # credit assignment
        loss.backward()
# update model weights
        optimizer.step()
        torch.save(model.state_dict(), 'model_ME.pt'+str(epoch))
# Out:
# 0
# tensor(26.5542, grad_fn=<MseLossBackward>)
# tensor(15.2217, grad_fn=<MseLossBackward>)
# tensor(7.9414, grad_fn=<MseLossBackward>)
# tensor(3.5734, grad_fn=<MseLossBackward>)
# tensor(1.8725, grad_fn=<MseLossBackward>)
# tensor(1.1587, grad_fn=<MseLossBackward>)
# tensor(1.3098, grad_fn=<MseLossBackward>)
# tensor(3.0675, grad_fn=<MseLossBackward>)
# tensor(3.8090, grad_fn=<MseLossBackward>)
# tensor(2.2539, grad_fn=<MseLossBackward>)
# 1
# tensor(2.5739, grad_fn=<MseLossBackward>)
# tensor(2.2505, grad_fn=<MseLossBackward>)
# tensor(1.2159, grad_fn=<MseLossBackward>)
# tensor(0.9566, grad_fn=<MseLossBackward>)
# tensor(2.1333, grad_fn=<MseLossBackward>)
# tensor(4.2698, grad_fn=<MseLossBackward>)
# tensor(2.7822, grad_fn=<MseLossBackward>)
# tensor(2.3438, grad_fn=<MseLossBackward>)
# tensor(2.2816, grad_fn=<MseLossBackward>)
# tensor(3.5918, grad_fn=<MseLossBackward>)
# 2
# tensor(1.2551, grad_fn=<MseLossBackward>)
# tensor(1.7526, grad_fn=<MseLossBackward>)
# tensor(2.4426, grad_fn=<MseLossBackward>)
# tensor(2.5976, grad_fn=<MseLossBackward>)
# tensor(1.6238, grad_fn=<MseLossBackward>)
# tensor(0.8675, grad_fn=<MseLossBackward>)
# tensor(0.8718, grad_fn=<MseLossBackward>)
# tensor(1.0313, grad_fn=<MseLossBackward>)
# tensor(1.0662, grad_fn=<MseLossBackward>)
# tensor(2.2449, grad_fn=<MseLossBackward>)
# 3
# tensor(1.2502, grad_fn=<MseLossBackward>)
# tensor(1.0868, grad_fn=<MseLossBackward>)
# tensor(0.9354, grad_fn=<MseLossBackward>)
# tensor(0.8539, grad_fn=<MseLossBackward>)
# tensor(0.7277, grad_fn=<MseLossBackward>)
# tensor(1.0148, grad_fn=<MseLossBackward>)
# tensor(0.8459, grad_fn=<MseLossBackward>)
# tensor(1.0249, grad_fn=<MseLossBackward>)
# tensor(1.0336, grad_fn=<MseLossBackward>)
# tensor(1.8163, grad_fn=<MseLossBackward>)
# 4
# tensor(1.2611, grad_fn=<MseLossBackward>)
# tensor(1.1900, grad_fn=<MseLossBackward>)
# tensor(1.0120, grad_fn=<MseLossBackward>)
# tensor(0.8708, grad_fn=<MseLossBackward>)
# tensor(0.7379, grad_fn=<MseLossBackward>)
# tensor(0.8047, grad_fn=<MseLossBackward>)
# tensor(0.9959, grad_fn=<MseLossBackward>)
# tensor(0.9300, grad_fn=<MseLossBackward>)
# tensor(0.9905, grad_fn=<MseLossBackward>)
# tensor(1.5188, grad_fn=<MseLossBackward>)
# 5
# tensor(1.0528, grad_fn=<MseLossBackward>)
# tensor(0.9579, grad_fn=<MseLossBackward>)
# tensor(0.8893, grad_fn=<MseLossBackward>)
# tensor(0.7656, grad_fn=<MseLossBackward>)
# tensor(0.6935, grad_fn=<MseLossBackward>)
# tensor(0.7416, grad_fn=<MseLossBackward>)

# %%
# Out:
# tensor([-0.2080, -0.2055, -0.0272, -0.2931, -0.3325, -0.1976, -0.1750, -0.2390,
#         -0.1254, -0.0871, -0.3926, -0.1047, -0.0020, -0.1189, -0.2423, -0.3211,
#         -0.2635, -0.3402, -0.0896, -0.2739, -0.1207, -0.1528, -0.1230, -0.1966,
#         -0.1613, -0.2073, -0.2206, -0.3550, -0.0750, -0.1872, -0.1096, -0.2785,
#         -0.1281, -0.2639, -0.1799, -0.2709, -0.1085, -0.1472, -0.1397, -0.2089,
#         -0.1146, -0.0718, -0.0262, -0.1870, -0.2033, -0.0842, -0.0651, -0.2398,
#         -0.1572,  0.0630,  0.0632, -0.3426, -0.2343, -0.1987, -0.3344, -0.0406,
#         -0.0389, -0.2417, -0.2236, -0.1940, -0.0938, -0.1367, -0.2414, -0.2096])

# %%
model.load_state_dict(torch.load('model.pt19'))
from numpy import vstack
from scipy.stats.stats import pearsonr
from sklearn.metrics import mean_absolute_error as mae
import sklearn
import math
print('sg')

import numpy as np
def evaluate_model(test_dl, model):
    predictions, actuals = list(), list()
    k=0
    for i, (inputs, targets) in enumerate(test_dl):
       # if k==0:
            # evaluate the model on the test set
            yhat = model(inputs)
            yhat=yhat.reshape(yhat.shape[0])
            print(yhat)
            # retrieve numpy array
            yhat = yhat.detach().numpy()
            actual = targets.numpy()
           # actual = actual.reshape((len(actual), 1))
            print(np.corrcoef(yhat,actual))
            mse1= sklearn.metrics.mean_squared_error(yhat,actual) 
            mse1=math.sqrt(mse1)
            print(mse1)
            print(mae(yhat,actual))
            # round to class values
            #yhat = yhat.round()
            # store
            #predictions.append(yhat)
            #actuals.append(actual)
          #  k=k+1
    #predictions, actuals = vstack(predictions), vstack(actuals)
    #print(predictions)
    #print(actuals)
    # calculate accuracy
   # acc = accuracy_score(actual, yhat)
    return acc
print(evaluate_model(test, model))
# Out:
# sg
# tensor([2.7825, 2.2440, 2.2639, 3.1180, 2.6534, 2.3763, 3.0532, 3.1199, 4.3944,
#         3.0688, 3.2571, 3.2865, 2.6643, 3.0057, 3.1984, 3.4432, 2.3019, 2.6816,
#         3.3891, 2.7769, 2.4148, 2.6045, 2.5508, 2.1668, 2.3654, 3.7868, 4.1418,
#         3.1677, 2.6981, 2.3065, 3.1062, 2.7762, 2.8231, 2.2788, 2.2624, 2.5455,
#         3.6733, 2.6314, 2.5910, 2.4809, 2.0392, 2.2006, 4.3681, 3.1743, 3.9812,
#         3.9060, 3.8658, 2.8200, 4.1834, 3.4921, 2.6794, 3.4869, 2.7570, 2.3393,
#         2.6086, 2.2425, 2.8989, 3.2039, 2.3681, 2.7545, 2.7694, 4.0968, 2.3354,
#         3.9977, 4.7810, 3.8643, 2.5080, 4.2298, 2.9676, 3.6307, 3.8407, 2.7562,
#         2.7571, 2.9079, 2.5504, 3.9988, 3.8693, 2.3976, 2.4375, 2.3804, 3.8202,
#         2.3762, 2.2492, 2.3353, 2.7590, 2.0807, 2.4629, 2.6229, 3.5647, 3.9299,
#         2.2794, 3.5034, 2.8642, 2.6997, 2.5976, 3.1501, 3.7885, 2.6813, 2.4826,
#         3.7134, 3.1318, 2.4338, 2.9254, 3.4030, 2.6059, 2.3496, 2.4282, 3.7213,
#         3.2971, 2.4726, 3.0121, 3.3491, 2.8182, 2.8695, 3.4226, 2.6363, 2.4561,
#         2.9576, 2.7017, 3.9455, 2.8347, 3.6488, 2.4636, 4.0229, 3.0202, 2.4647,
#         3.1490, 3.5188], grad_fn=<ViewBackward>)
# [[1.         0.72398631]
#  [0.72398631 1.        ]]
# 0.45928553200000877
# 0.35021772625529773
#         2.5153, 3.7106, 3.7089, 4.1775, 2.4159, 2.4160, 2.6822, 2.5047, 3.0291,
#         2.4371, 3.1069, 2.5566, 2.8993, 2.5415, 2.4583, 3.7309, 2.5468, 3.4815,
#         2.2148, 2.9682, 2.9273, 2.3546, 2.5429, 2.4522, 2.1507, 2.2916, 3.1380,
#         4.5686, 2.8614, 3.0128, 2.2497, 3.0348, 2.9044, 2.3366, 3.4775, 3.9664,
#         3.2454, 2.8748], grad_fn=<ViewBackward>)
# [[1.         0.74468755]
#  [0.74468755 1.        ]]
# 0.4827033428330281
# 0.37586148667192465
# tensor([2.8413, 2.0454, 4.2200, 3.2691, 3.5409, 2.8676, 2.3753, 2.9783, 2.8628,
#         2.6083, 2.3997, 3.3639, 3.4902, 2.2670, 3.9690, 3.9552, 2.7675, 2.8732,
#         3.3034, 3.3604, 2.7385, 2.5319, 3.4578, 2.3281, 3.9462, 3.6027, 3.2896,
#         2.1786, 3.8263, 2.7462, 2.3188, 2.1501, 2.2042, 2.7020, 3.1627, 2.6325,
#         3.7316, 2.9452, 2.9637, 2.6268, 4.5663, 2.0172, 4.0426, 2.6539, 3.8781,
#         3.2535, 2.2889, 2.5497, 2.5195, 3.2535, 2.0477, 2.5140, 3.0239, 2.3695,
#         2.4957, 3.4204, 2.1829, 3.0052, 2.6881, 2.5016, 2.5581, 3.2379, 2.9972,
#         2.8414, 2.6739, 3.5080, 3.3859, 4.1029, 3.7549, 2.6512, 3.6726, 2.9966,
#         2.4491, 3.5236, 2.5958, 2.5990, 2.2231, 3.6693, 3.0105, 2.1044, 4.5799,
#         3.2173, 2.0855, 3.1160, 2.6475, 2.5955, 2.6710, 3.5631, 2.2752, 4.3423,
#         2.6885, 2.7854, 2.6538, 3.5761, 2.4563, 2.9001, 2.8693, 2.4698, 2.6371,
#         3.8592, 2.4213, 3.5115, 2.5162, 2.3910, 2.4181, 2.6671, 2.7846, 2.4278,
#         3.3874, 3.7929, 2.9584, 2.9209, 4.3278, 3.6376, 2.7590, 4.0208, 3.0433,
#         4.1369, 2.3128, 3.0067, 2.6111, 2.8420, 2.6456, 4.3009, 3.3734, 2.2782,
#         3.6272, 2.9860], grad_fn=<ViewBackward>)
# [[1.         0.72772367]
#  [0.72772367 1.        ]]
# 0.4975536190050271
# 0.3843404541660547
# tensor([3.8766, 2.1203, 2.8282, 4.1892, 3.2049, 4.1286, 3.0754, 3.9108, 2.8174,
#         3.1075, 2.4654, 3.9498, 2.3492, 3.1287, 2.2435, 3.0356, 2.4826, 2.2345,
#         2.4167, 3.0876, 2.5086, 2.8651, 2.7192, 2.7758],
#        grad_fn=<ViewBackward>)
# [[1.         0.66157572]
#  [0.66157572 1.        ]]
# 0.5475407728772461
# 0.41740338340632127
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-099f68b16d73> in <module>
#      38    # acc = accuracy_score(actual, yhat)
#      39     return acc
# ---> 40 print(evaluate_model(test, model))
#
# <ipython-input-9-099f68b16d73> in evaluate_model(test_dl, model)
#      37     # calculate accuracy
#      38    # acc = accuracy_score(actual, yhat)
# ---> 39     return acc
#      40 print(evaluate_model(test, model))
#
# NameError: name 'acc' is not defined
